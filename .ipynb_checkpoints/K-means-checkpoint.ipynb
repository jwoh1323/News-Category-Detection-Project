# %% [markdown]
# ## K Means Clustering with scraped data

# %%
import d2l
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from mxnet.contrib import text
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('scraped_data.csv')
df.head()
# Out:
#                                             headline  \
# 0  From Loss Of Smell To 'COVID Toes': What Exper...
# 1  As Businesses Reopen, A Fight Is Brewing Over ...
# 2  Michigan Legislature Sues Gov. Whitmer, Seekin...
# 3  The Risk Of Coronavirus In Afghanistan's Priso...
# 4  Officials Investigating Multiple COVID-19 Deat...
#
#                                              article      date  \
# 0  It's not just a fever and dry cough. For milde...  5/6/2020
# 1  Republican Senate Leader Mitch McConnell insis...  5/6/2020
# 2  The legislators say the governor is acting ill...  5/6/2020
# 3  The Taliban accuse the government of spreading...  5/6/2020
# 4  Multiple investigations are underway at the So...  5/6/2020
#
#                    category
# 0            Goats and Soda
# 1  Coronavirus Live Updates
# 2  Coronavirus Live Updates
# 3  Coronavirus Live Updates
# 4  Coronavirus Live Updates

# %%
pd.value_counts(df['category'])
# Out:
# The Two-Way                                             5652
# Politics                                                3709
# National                                                2816
# Shots - Health News                                     2069
# Goats and Soda                                          1159
#                                                         ...
# Russia Investigations: Election Meddling And Fallout       1
# Let's Talk About Sex                                       1
# Concerts                                                   1
# Election 2016 Results                                      1
# The New Clash Between Free Speech And Privacy              1
# Name: category, Length: 242, dtype: int64

# %% [markdown]
# The data source used is 27k articles scraped from NPR news archive. As shown above, there are 242 categories associated with these articles.It's not only too many categories for articles, but a lot of them are not really a category like 'The Two-Way' and 'Goats and Soda', which are more like their article series name, so I decided to do unsupervised learning to see if it categorize better. The method I choose is K-Means Clustering.

# %% [markdown]
# ### K-Means with news headlines

# %%
# Choosing headlines column

df_headline = df['headline']

len(df_headline)
# Out:
# 27005

# %%
df_headline = d2l.tokenize(df_headline, token = 'word')

# %%
df_headline[0]
# Out:
# ['From',
#  'Loss',
#  'Of',
#  'Smell',
#  'To',
#  "'COVID",
#  "Toes':",
#  'What',
#  'Experts',
#  'Are',
#  'Learning',
#  'About',
#  'Symptoms']

# %%
vocab = d2l.Vocab(df_headline, min_freq=4, reserved_tokens=['<pad>'])

print(list(vocab.token_to_idx.items())[0:10])
# Out:
# [('<unk>', 0), ('<pad>', 1), ('To', 2), ('In', 3), ('The', 4), ('Of', 5), ('A', 6), ('For', 7), ('And', 8), ('On', 9)]

# %%
d2l.set_figsize((3.5, 2.5))
d2l.plt.hist([len(line) for line in df_headline], bins=range(0, 30, 5));

# %%
num_steps=30

df_headline = np.array([d2l.truncate_pad(
    vocab[line], num_steps, vocab['<pad>']) for line in df_headline])

# %%
df_headline
# Out:
# array([[  19, 1227,    5, ...,    1,    1,    1],
#        [  16,  932,    0, ...,    1,    1,    1],
#        [ 902, 2981,  753, ...,    1,    1,    1],
#        ...,
#        [   0,    8, 5013, ...,    1,    1,    1],
#        [  52,    3, 7100, ...,    1,    1,    1],
#        [ 259,  200, 1039, ...,    1,    1,    1]])

# %%
df_headline.shape
# Out:
# (27005, 30)

# %%
wcss = []
for i in range(1, 51):
    kmeans = KMeans(n_clusters=i,random_state=0).fit(df_headline)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 51), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
sil = []

for i in range(2, 51):
    kmeans = KMeans(n_clusters=i).fit(df_headline)
    labels = kmeans.labels_
    sil.append(silhouette_score(df_headline, labels, metric = 'euclidean'))
plt.plot(range(2, 51), sil)
plt.title('Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
for i in zip(range(2,51),sil):
    print(f" Number of Clusters : {i[0]}, Silhouette Score: {i[1]}")
# Out:
#  Number of Clusters : 2, Silhouette Score: 0.16302447057622277
#  Number of Clusters : 3, Silhouette Score: 0.16243064859548334
#  Number of Clusters : 4, Silhouette Score: 0.16281711206663352
#  Number of Clusters : 5, Silhouette Score: 0.1687230428171619
#  Number of Clusters : 6, Silhouette Score: 0.17370186653513
#  Number of Clusters : 7, Silhouette Score: 0.1790828696643839
#  Number of Clusters : 8, Silhouette Score: 0.18270347911192256
#  Number of Clusters : 9, Silhouette Score: 0.188073264400938
#  Number of Clusters : 10, Silhouette Score: 0.19262099769267926
#  Number of Clusters : 11, Silhouette Score: 0.19618268496499316
#  Number of Clusters : 12, Silhouette Score: 0.1506421009870129
#  Number of Clusters : 13, Silhouette Score: 0.20124130378950575
#  Number of Clusters : 14, Silhouette Score: 0.1556148353492832
#  Number of Clusters : 15, Silhouette Score: 0.15339687153199988
#  Number of Clusters : 16, Silhouette Score: 0.2009646022615173
#  Number of Clusters : 17, Silhouette Score: 0.14527833040414
#  Number of Clusters : 18, Silhouette Score: 0.14008109903122024
#  Number of Clusters : 19, Silhouette Score: 0.14068698592778658
#  Number of Clusters : 20, Silhouette Score: 0.14984913298743346
#  Number of Clusters : 21, Silhouette Score: 0.13122614798210228
#  Number of Clusters : 22, Silhouette Score: 0.12697308972060303
#  Number of Clusters : 23, Silhouette Score: 0.1408879941886211
#  Number of Clusters : 24, Silhouette Score: 0.1315654450533232
#  Number of Clusters : 25, Silhouette Score: 0.12033577089366818
#  Number of Clusters : 26, Silhouette Score: 0.1353986288608258
#  Number of Clusters : 27, Silhouette Score: 0.12213879507176552
#  Number of Clusters : 28, Silhouette Score: 0.1367375892228595
#  Number of Clusters : 29, Silhouette Score: 0.12128876384757166
#  Number of Clusters : 30, Silhouette Score: 0.11440078572213772
#  Number of Clusters : 31, Silhouette Score: 0.12052194504193142
#  Number of Clusters : 32, Silhouette Score: 0.11267469676888327
#  Number of Clusters : 33, Silhouette Score: 0.1313287599447588
#  Number of Clusters : 34, Silhouette Score: 0.11404620721351298
#  Number of Clusters : 35, Silhouette Score: 0.11889376333553733
#  Number of Clusters : 36, Silhouette Score: 0.12027838679575842
#  Number of Clusters : 37, Silhouette Score: 0.1293493814411258
#  Number of Clusters : 38, Silhouette Score: 0.11454465780826344
#  Number of Clusters : 39, Silhouette Score: 0.12158649667802643
#  Number of Clusters : 40, Silhouette Score: 0.1165980438986705
#  Number of Clusters : 41, Silhouette Score: 0.12525991549722978
#  Number of Clusters : 42, Silhouette Score: 0.11774041085777277
#  Number of Clusters : 43, Silhouette Score: 0.11782093752644499
#  Number of Clusters : 44, Silhouette Score: 0.11350724547173988
#  Number of Clusters : 45, Silhouette Score: 0.11898948800847008
#  Number of Clusters : 46, Silhouette Score: 0.12009900657200605
#  Number of Clusters : 47, Silhouette Score: 0.1282664673408574
#  Number of Clusters : 48, Silhouette Score: 0.11107437785262414
#  Number of Clusters : 49, Silhouette Score: 0.12110578588722007
#  Number of Clusters : 50, Silhouette Score: 0.1318933486895935

# %% [markdown]
# ### K-Means with news articles

# %%
df_article = df['article']

len(df_article)
# Out:
# 27005

# %%
df_article = d2l.tokenize(df_article, token = 'word')

# %%
df_article[0]
# Out:
# ["It's",
#  'not',
#  'just',
#  'a',
#  'fever',
#  'and',
#  'dry',
#  'cough.',
#  'For',
#  'milder',
#  'cases',
#  'of',
#  'COVID-19,',
#  'the',
#  'array',
#  'of',
#  'symptoms',
#  'can',
#  'include',
#  'headaches,',
#  'fatigue,',
#  'loss',
#  'of',
#  'smell',
#  'and',
#  'even',
#  'lesions',
#  'on',
#  'the',
#  'feet',
#  'known',
#  'as',
#  '"COVID',
#  'toes."']

# %%
vocab = d2l.Vocab(df_article, min_freq=4, reserved_tokens=['<pad>'])

print(list(vocab.token_to_idx.items())[0:10])
# Out:
# [('<unk>', 0), ('<pad>', 1), ('the', 2), ('to', 3), ('of', 4), ('a', 5), ('and', 6), ('in', 7), ('The', 8), ('for', 9)]

# %%
d2l.set_figsize((3.5, 2.5))
d2l.plt.hist([len(line) for line in df_article], bins=range(0, 70, 5));

# %%
num_steps=70

df_article = np.array([d2l.truncate_pad(
    vocab[line], num_steps, vocab['<pad>']) for line in df_article])

# %%
df_article
# Out:
# array([[ 100,   49,   96, ...,    1,    1,    1],
#        [ 134,  147, 2256, ...,    1,    1,    1],
#        [   8, 6595,   50, ...,    1,    1,    1],
#        ...,
#        [  42,  264, 1072, ...,    1,    1,    1],
#        [ 912,    5, 3369, ...,    1,    1,    1],
#        [ 377,   66,  182, ...,    1,    1,    1]])

# %%
df_article.shape
# Out:
# (27005, 70)

# %%
wcss = []
for i in range(1, 51):
    kmeans = KMeans(n_clusters=i,random_state=0).fit(df_article)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 51), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
sil = []

for i in range(2, 51):
    kmeans = KMeans(n_clusters=i).fit(df_article)
    labels = kmeans.labels_
    sil.append(silhouette_score(df_article, labels, metric = 'euclidean'))
plt.plot(range(2, 51), sil)
plt.title('Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
for i in zip(range(2,51),sil):
    print(f" Number of Clusters : {i[0]}, Silhouette Score: {i[1]}")
# Out:
#  Number of Clusters : 2, Silhouette Score: 0.08149817854131661
#  Number of Clusters : 3, Silhouette Score: 0.06860946450067375
#  Number of Clusters : 4, Silhouette Score: 0.07232272884205153
#  Number of Clusters : 5, Silhouette Score: 0.07252717911233368
#  Number of Clusters : 6, Silhouette Score: 0.07379756736133664
#  Number of Clusters : 7, Silhouette Score: 0.06873842152948541
#  Number of Clusters : 8, Silhouette Score: 0.07340349744080107
#  Number of Clusters : 9, Silhouette Score: 0.0722208352795655
#  Number of Clusters : 10, Silhouette Score: 0.07141115557382172
#  Number of Clusters : 11, Silhouette Score: 0.07077091763912537
#  Number of Clusters : 12, Silhouette Score: 0.07104902421839367
#  Number of Clusters : 13, Silhouette Score: 0.0704059885168363
#  Number of Clusters : 14, Silhouette Score: 0.07011059157057274
#  Number of Clusters : 15, Silhouette Score: 0.06779475879776385
#  Number of Clusters : 16, Silhouette Score: 0.0680469305914245
#  Number of Clusters : 17, Silhouette Score: 0.06740888832289672
#  Number of Clusters : 18, Silhouette Score: 0.06573536531732023
#  Number of Clusters : 19, Silhouette Score: 0.06477650905772346
#  Number of Clusters : 20, Silhouette Score: 0.06452401651652097
#  Number of Clusters : 21, Silhouette Score: 0.06519268384054229
#  Number of Clusters : 22, Silhouette Score: 0.06068895117874959
#  Number of Clusters : 23, Silhouette Score: 0.060731820121691274
#  Number of Clusters : 24, Silhouette Score: 0.05901175796805083
#  Number of Clusters : 25, Silhouette Score: 0.057813450130438995
#  Number of Clusters : 26, Silhouette Score: 0.05549870479068676
#  Number of Clusters : 27, Silhouette Score: 0.05466383736111966
#  Number of Clusters : 28, Silhouette Score: 0.055942578924760365
#  Number of Clusters : 29, Silhouette Score: 0.05500396914334992
#  Number of Clusters : 30, Silhouette Score: 0.051875147802554485
#  Number of Clusters : 31, Silhouette Score: 0.05018632016582395
#  Number of Clusters : 32, Silhouette Score: 0.04856211260565972
#  Number of Clusters : 33, Silhouette Score: 0.04687073285657163
#  Number of Clusters : 34, Silhouette Score: 0.04877182596936665
#  Number of Clusters : 35, Silhouette Score: 0.04684556868393985
#  Number of Clusters : 36, Silhouette Score: 0.04709574501809489
#  Number of Clusters : 37, Silhouette Score: 0.019476667011317304
#  Number of Clusters : 38, Silhouette Score: 0.029134694931953958
#  Number of Clusters : 39, Silhouette Score: 0.02108854793274621
#  Number of Clusters : 40, Silhouette Score: 0.019594370416184722
#  Number of Clusters : 41, Silhouette Score: 0.021789826260370546
#  Number of Clusters : 42, Silhouette Score: 0.02869894361551196
#  Number of Clusters : 43, Silhouette Score: 0.024116362308043364
#  Number of Clusters : 44, Silhouette Score: 0.00897200919945729
#  Number of Clusters : 45, Silhouette Score: 0.02780399519670227
#  Number of Clusters : 46, Silhouette Score: 0.02124852331460851
#  Number of Clusters : 47, Silhouette Score: 0.030266695575317904
#  Number of Clusters : 48, Silhouette Score: 0.01197403790527492
#  Number of Clusters : 49, Silhouette Score: 0.017686582500592418
#  Number of Clusters : 50, Silhouette Score: 0.02433822536275903
